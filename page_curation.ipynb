# %%
import pandas as pd
import numpy as np

# %%
TOPICS_PATH = '/dlabdata1/turkish_wiki'

# %%
topics_df = pd.read_csv(f"{TOPICS_PATH}/trwiki_topics.csv")

# %%
topics_df
# Out:
#        wiki_db         qid      pid  num_outlinks  \
# 0       trwiki     Q216912     2173           373
# 1       trwiki       Q6327     2952            62
# 2       trwiki       Q2821     3250           621
# 3       trwiki     Q133168    22339           249
# 4       trwiki    Q1404923    38588            46
# ...        ...         ...      ...           ...
# 385014  trwiki    Q4540622  2832399             3
# 385015  trwiki   Q13499227  2846495            10
# 385016  trwiki  Q102129184  2847913            18
# 385017  trwiki         NaN  2876177             9
# 385018  trwiki         NaN  2878496             5
#
#         Culture.Biography.Biography*  Culture.Biography.Women  \
# 0                              0.004                    0.000
# 1                              0.000                    0.000
# 2                              0.822                    0.066
# 3                              0.971                    0.095
# ...
